# %%
import pandas as pd
import seaborn as sns

# %%
col_vals=['Status of Saving account','Loan Duration','Credit History','Loan Purpose','Loan Amount',' Savings','Present job since','Installment / Income %','Marital Status + Sex','Application type','Residing since','Property (Security)','Age in years','Other installments','House ownership','No of cards','Skill','DependentsNo','Telephone','Foreign worker','Outcome']

# %%
data=pd.read_csv('GermanFinal.csv')
data.columns=col_vals
data.head()
# Out:
#    Status of Saving account  Loan Duration  Credit History  Loan Purpose  \
# 0                         2             48               2             1
# 1                         4             12               4             1
# 2                         1             42               2             1
# 3                         1             24               3             1
# 4                         4             36               2             5
#
#    Loan Amount   Savings  Present job since  Installment / Income %  \
# 0            3         2                  1                      22
# 1            4         3                  1                      49
# 2            4         4                  2                      45
# 3            3         4                  4                      53
# 4            3         4                  4                      35
#
#    Marital Status + Sex  Application type  ...  Property (Security)  \
# ...

# %%
data['Outcome'] = data['Outcome'].replace([2],'X')
data['Outcome'] = data['Outcome'].replace([1],'Y')
data['Outcome'] = data['Outcome'].replace(['X'],1)
data['Outcome'] = data['Outcome'].replace(['Y'],0)
data.head()
# Out:
#    Status of Saving account  Loan Duration  Credit History  Loan Purpose  \
# 0                         2             48               2             1
# 1                         4             12               4             1
# 2                         1             42               2             1
# 3                         1             24               3             1
# 4                         4             36               2             5
#
#    Loan Amount   Savings  Present job since  Installment / Income %  \
# 0            3         2                  1                      22
# 1            4         3                  1                      49
# 2            4         4                  2                      45
# 3            3         4                  4                      53
# 4            3         4                  4                      35
#
#    Marital Status + Sex  Application type  ...  Property (Security)  \
# ...

# %% [markdown]
# from pycaret import classification
# classification.setup(data=data,target="Outcome",session_id=123,normalize=True)
# best_model=compare_models()

# %%
sns.countplot(data['Outcome'])

# %%
from pycaret.classification import *

# %%
exp_clf101 = setup(data=data, target="Outcome", session_id=123, normalize=True)
# Out:
# <style  type="text/css" >
#     #T_76b66ad8_2d8e_11eb_bc51_53d715196cf1row29_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_76b66ad8_2d8e_11eb_bc51_53d715196cf1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_76b66ad8_2d8e_11eb_bc51_53d715196cf1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_76b66ad8_2d8e_11eb_bc51_53d715196cf1row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_76b66ad8_2d8e_11eb_bc51_53d715196cf1row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_76b66ad8_2d8e_11eb_bc51_53d715196cf1level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1 th {
#           text-align: left;
#     }    #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_8d4acffa_2d8e_11eb_bc51_53d715196cf1row0_col5 {
# ...
